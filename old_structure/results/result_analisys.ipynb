# %%
# Out:
# Failed to load outputs/mistral7binstruct/run5/clock/weight/mass/grams_20250616-224848-171163.json: Expecting ',' delimiter: line 2 column 406 (char 407)
# Failed to load outputs/mistral7binstruct/run3/clock/weight/mass/grams_20250618-033519-809940.json: Expecting ',' delimiter: line 2 column 406 (char 407)
# Failed to load outputs/mistral7binstruct/run2/clock/weight/mass/grams_20250617-225757-830317.json: Expecting ',' delimiter: line 2 column 406 (char 407)
# Failed to load outputs/mistral7binstruct/run1/clock/weight/mass/grams_20250617-181618-080247.json: Expecting ',' delimiter: line 2 column 406 (char 407)
# Failed to load outputs/mistral7binstruct/run4/clock/weight/mass/grams_20250617-130231-286287.json: Expecting ',' delimiter: line 2 column 406 (char 407)
# Failed to load outputs/metallama31-8b-instruct/run5/microwave/speed/speed/meters_per_second_20250619-065628-273731.json: Expecting ',' delimiter: line 2 column 1181 (char 1182)
# ...
